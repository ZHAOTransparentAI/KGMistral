# %% [markdown]
# # Cosine Similarity between Two Word Embeddings

# %%
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from scipy.spatial.distance import cosine
import re

# %% [markdown]
# ## Find Most 5 Similarest Entities with BERT
# Our statistical results for similarity matching show that extracting the 5 most similar entities can cover the most exemplary question.
#
# I tried to use BERT and SpaCy models to perform similarity matching on entities. Finally, I found that bert-base-uncased can more efficiently find the most relevant entities for most problems in the first five, while other models cannot. There has been a significant improvement. For example, spacy's en_core_web_lg similarity results are much irrelevant to given entities.

# %%
# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
def bert_encode(text):
    encoded_input = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    with torch.no_grad():
        output = model(**encoded_input)
    embedding = output.last_hidden_state.mean(dim=1).squeeze()
    return embedding

# %% [markdown]
# he cosine similarity between the two embeddings is calculated, which is 1 - cosine_distance. This gives a similarity score between 0 and 1, where 1 means identical and 0 means completely dissimilar.

# %%
def compute_similarity(text1, text2):
    # Encode the texts
    embedding1 = bert_encode(text1)
    embedding2 = bert_encode(text2)
    # Ensure embeddings are numpy 1-D arrays for cosine similarity calculation
    embedding1_np = embedding1.cpu().numpy() if embedding1.is_cuda else embedding1.numpy()
    embedding2_np = embedding2.cpu().numpy() if embedding2.is_cuda else embedding2.numpy()
    # Compute cosine similarity
    return 1 - cosine(embedding1_np, embedding2_np)

# %% [markdown]
# This function extracts abbreviations from text within parentheses. If no parentheses are found, it returns the original text.

# %%
def extract_abbreviation(text):
    if isinstance(text, str):
        match = re.search(r'\(([^)]+)\)', text)
        return match.group(1) if match else text
    else:
        return text

# %%
def find_most_similar_entities(df, entity_column):
    # Read data from an Excel file
    df_entity = pd.read_excel('/content/extracted_headentity_list.xlsx')
    df_entity['entity_abb'] = df_entity['entity_label'].apply(extract_abbreviation)
    df_entity['entity_lowercase'] = df_entity['entity_abb'].str.lower()

    def process_entity(question_entity):
        similarity_scores = {}
        threshold = 0.5  # You may need to adjust this based on BERT's behavior

        for index, row in df_entity.iterrows():
            if pd.isna(row['entity_lowercase']):
                continue

            similarity = compute_similarity(question_entity.lower(), row['entity_lowercase'])
            if similarity > threshold:
                similarity_scores[index] = similarity

        top_5_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:5]

        if top_5_similarities:
            similar_entities = [df_entity.at[index, 'entity_label'] for index, _ in top_5_similarities]
            entity_uris = [df_entity.at[index, 'entity_uri'] for index, _ in top_5_similarities]
            return similar_entities, entity_uris
        else:
            return None, None

    def process_entity_list(entity_list):
        similar_entities_list = []
        entity_uris_list = []

        for entity in entity_list.split(','):
            entity = entity.strip()
            if entity:
                similar_entities, entity_uris = process_entity(entity)
                if similar_entities and entity_uris:
                    similar_entities_list.extend(similar_entities)
                    entity_uris_list.extend(entity_uris)

        if similar_entities_list:
            return similar_entities_list, entity_uris_list
        else:
            return None, None

    results = df[entity_column].apply(lambda x: process_entity(x) if isinstance(x, str) and ',' not in x else process_entity_list(x) if isinstance(x, str) else (None, None))
    df['Similar Entities'] = results.apply(lambda x: x[0] if x else None)
    df['Entity URIs'] = results.apply(lambda x: x[1] if x else None)
    return df

df = pd.read_excel('EntityandRelationfromQuestion.xlsx')
# df = df.head(2) # Just demonstrating on the first second row, because run the whole dataset will take a long time
# Assuming 'df' is your DataFrame with a column 'Named Entities'
df = find_most_similar_entities(df, 'Named Entities')  # Replace 'Named Entities' with the actual column name

# Save the modified DataFrame to an Excel file
df.to_excel("SimilarEntities5.xlsx", index=False)
df
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6             Molecular Dynamics" Software?
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   [computational materials science, Computationa...
# 1   [Elemental Multiperspective Material Ontology ...
# 2        [datasets, dataset, Image data, data portal]
# 3   [Ebrahim Norouzi, Ahmad Zainul Ihsan, Mirza Mo...
# 4          [paraview, ParaView, data portal, dataset]
# 5   [Dr.  Volker Hofmann, Niklas Siemer, Dr. Tilma...
# 6   [Atomic Simulation Recipes, Workshop: From Ele...
# 7   [Molecular Dynamics (MD), Crystallography Open...
# 8   [computational materials science, Computationa...
# 9                      [Pyiron, Pyrho, pyDOE, cython]
# 10  [Analytic bond-order potentials, Mechanical Be...
# 11  [Python scripts, Java, python, Python, Materia...
# 12  [electronic lab notebook, Jupyter notebooks, E...
# 13  [molecular dynamics, Visual Molecular Dynamics...
# 14  [computational materials science, Computationa...
# 15  [Elk, NOMAD, Novel Materials Discovery (NOMAD)...
# 16  [Ontologies for Materials Science, Computation...
# 17  [acronym, Silicon, SIRIUS, Crystallography Ope...
# 18  [acronym, project, project, Project, Tomograph...
# 19  [ontology, ontology matching, The MatWerk onto...
# 20  [Materials Project API, HybriD³ materials data...
# 21        [specification, Silicon, acronym, software]
# 22  [MatDB Online, MatDB, Organic Materials Databa...
# 23  [Proprietary license, Proprietary commercial s...
# 24  [Materials Cloud, Materials Commons, Materials...
# 25  [Bundesanstalt für Materialforschung und -prüf...
# 26  [Mechanics of Materials, mechanics of material...
# 27  [Transmission electron microscopy, X-ray micro...
# 28  [Elastic Constant Demo Data, Elastic Constant ...
# 29  [hardness data, educational resource, Carolina...
# 30  [hardness data, educational resource, Carolina...
# 31      [pacemaker, Atomman, matador, Plant movement]
# 32  [hardness data, educational resource, Carolina...
# 33  [hardness data, educational resource, Carolina...
# 34  [Bochkarev, A., Lysogorskiy, Y., Menon, S., Qa...
# 35  [hardness data, educational resource, Carolina...
# 36  [Bundesanstalt für Materialforschung und -prüf...
#
#                                           Entity URIs
# 0   [http://demo.fiz-karlsruhe.de/matwerk/E67431, ...
# 1   [http://demo.fiz-karlsruhe.de/matwerk/E1126751...
# 2   [http://demo.fiz-karlsruhe.de/matwerk/E1172216...
# 3   [http://demo.fiz-karlsruhe.de/matwerk/E15879, ...
# 4   [http://demo.fiz-karlsruhe.de/matwerk/E1231097...
# 5   [http://demo.fiz-karlsruhe.de/matwerk/E9912, h...
# 6   [http://demo.fiz-karlsruhe.de/matwerk/E552776,...
# 7   [http://demo.fiz-karlsruhe.de/matwerk/E61379, ...
# 8   [http://demo.fiz-karlsruhe.de/matwerk/E67431, ...
# 9   [http://demo.fiz-karlsruhe.de/matwerk/E457491,...
# 10  [http://demo.fiz-karlsruhe.de/matwerk/E40341, ...
# 11  [http://demo.fiz-karlsruhe.de/matwerk/E1198379...
# 12  [http://purls.helmholtz-metadaten.de/mwo/Elect...
# 13  [http://demo.fiz-karlsruhe.de/matwerk/E616496,...
# 14  [http://demo.fiz-karlsruhe.de/matwerk/E67431, ...
# 15  [http://demo.fiz-karlsruhe.de/matwerk/E444212,...
# 16  [http://demo.fiz-karlsruhe.de/matwerk/E1247883...
# 17  [http://purl.obolibrary.org/obo/NCIT_C93495, h...
# 18  [http://purl.obolibrary.org/obo/NCIT_C93495, h...
# 19  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 20  [http://demo.fiz-karlsruhe.de/matwerk/E547536,...
# 21  [http://nfdi.fiz-karlsruhe.de/ontology/Specifi...
# 22  [http://demo.fiz-karlsruhe.de/matwerk/E1146342...
# 23  [http://demo.fiz-karlsruhe.de/matwerk/E748254,...
# 24  [http://demo.fiz-karlsruhe.de/matwerk/E1027029...
# 25  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...
# 26  [http://demo.fiz-karlsruhe.de/matwerk/E52682, ...
# 27  [http://demo.fiz-karlsruhe.de/matwerk/E625404,...
# 28  [http://demo.fiz-karlsruhe.de/matwerk/E1247418...
# 29  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 30  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 31  [http://demo.fiz-karlsruhe.de/matwerk/E511556,...
# 32  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 33  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 34  [http://demo.fiz-karlsruhe.de/matwerk/E945626,...
# 35  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 36  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...

# %% [markdown]
# Note: The similarity matching above is not always effective. For example, entity'BAM reference data: results of ASTM E139 -11 creep tests on a reference material of Nimonic 75 nickel-base alloy' should contain such an entity "BAM reference data" within the top 5 similar entity.However, the top five matched entities may not contain the correct answer.
#
#
# This suggests that we need to improve our similarity matching methods for better results. This could serve as a future work. Here, we simply include entities from the knowledge graph that are relevant to entities mentioned in the question.

# %%
import pandas as pd
import ast  # Add this import to use ast.literal_eval

# Assuming you've already loaded your DataFrames
df_entity = pd.read_excel('/content/extracted_headentity_list.xlsx')
df = pd.read_excel('SimilarEntities5.xlsx')


# Function to safely convert string representations of lists to actual lists
def safe_list_eval(cell_value):
    try:
        # Attempt to evaluate the string as a list
        return ast.literal_eval(cell_value)
    except (ValueError, SyntaxError):
        # If there's an error (e.g., cell_value is not a string representation of a list), return a list with the original cell_value
        return [cell_value] if cell_value else []

# Initialize 'Similar Entities' and 'Entity URIs' columns as lists if they are not already and not empty
for i in range(len(df)):
    df.at[i, 'Similar Entities'] = safe_list_eval(df.at[i, 'Similar Entities'])
    df.at[i, 'Entity URIs'] = safe_list_eval(df.at[i, 'Entity URIs'])

# Iterate through each element in the "Named Entities" column of df
for i, named_entities in enumerate(df['Named Entities']):
    indexes = []
    # Iterate through df_entity and check each element
    for index, row in df_entity.iterrows():
        word = row['entity_label']
        if isinstance(word, str) and named_entities in word:
            indexes.append(index)

    if indexes:
        matched_entity_label = df_entity.at[indexes[-1], 'entity_label']
        matched_entity_uri = df_entity.at[indexes[-1], 'entity_uri']

        if matched_entity_label not in df.at[i, 'Similar Entities']:
            df.at[i, 'Similar Entities'].append(matched_entity_label)
            df.at[i, 'Entity URIs'].append(matched_entity_uri)

# Save the modified DataFrame to an Excel file
df.to_excel("SimilarEntities5+1.xlsx", index=False)
df
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6             Molecular Dynamics" Software?
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   [computational materials science, Computationa...
# 1   [Elemental Multiperspective Material Ontology ...
# 2   [datasets, dataset, Image data, data portal, F...
# 3   [Ebrahim Norouzi, Ahmad Zainul Ihsan, Mirza Mo...
# 4          [paraview, ParaView, data portal, dataset]
# 5   [Dr.  Volker Hofmann, Niklas Siemer, Dr. Tilma...
# 6   [Atomic Simulation Recipes, Workshop: From Ele...
# 7   [Molecular Dynamics (MD), Crystallography Open...
# 8   [computational materials science, Computationa...
# 9   [Pyiron, Pyrho, pyDOE, cython, https://github....
# 10  [Analytic bond-order potentials, Mechanical Be...
# 11  [Python scripts, Java, python, Python, Materia...
# 12  [electronic lab notebook, Jupyter notebooks, E...
# 13  [molecular dynamics, Visual Molecular Dynamics...
# 14  [computational materials science, Computationa...
# 15  [Elk, NOMAD, Novel Materials Discovery (NOMAD)...
# 16  [Ontologies for Materials Science, Computation...
# 17  [acronym, Silicon, SIRIUS, Crystallography Ope...
# 18  [acronym, project, project, Project, Tomograph...
# 19  [ontology, ontology matching, The MatWerk onto...
# 20  [Materials Project API, HybriD³ materials data...
# 21  [specification, Silicon, acronym, software, R....
# 22  [MatDB Online, MatDB, Organic Materials Databa...
# 23  [Proprietary license, Proprietary commercial s...
# 24  [Materials Cloud, Materials Commons, Materials...
# 25  [Bundesanstalt für Materialforschung und -prüf...
# 26  [Mechanics of Materials, mechanics of material...
# 27  [Transmission electron microscopy, X-ray micro...
# 28  [Elastic Constant Demo Data, Elastic Constant ...
# 29  [hardness data, educational resource, Carolina...
# 30  [hardness data, educational resource, Carolina...
# 31      [pacemaker, Atomman, matador, Plant movement]
# 32  [hardness data, educational resource, Carolina...
# 33  [hardness data, educational resource, Carolina...
# 34  [Bochkarev, A., Lysogorskiy, Y., Menon, S., Qa...
# 35  [hardness data, educational resource, Carolina...
# 36  [Bundesanstalt für Materialforschung und -prüf...
#
#                                           Entity URIs
# 0   [http://demo.fiz-karlsruhe.de/matwerk/E67431, ...
# 1   [http://demo.fiz-karlsruhe.de/matwerk/E1126751...
# 2   [http://demo.fiz-karlsruhe.de/matwerk/E1172216...
# 3   [http://demo.fiz-karlsruhe.de/matwerk/E15879, ...
# 4   [http://demo.fiz-karlsruhe.de/matwerk/E1231097...
# 5   [http://demo.fiz-karlsruhe.de/matwerk/E9912, h...
# 6   [http://demo.fiz-karlsruhe.de/matwerk/E552776,...
# 7   [http://demo.fiz-karlsruhe.de/matwerk/E61379, ...
# 8   [http://demo.fiz-karlsruhe.de/matwerk/E67431, ...
# 9   [http://demo.fiz-karlsruhe.de/matwerk/E457491,...
# 10  [http://demo.fiz-karlsruhe.de/matwerk/E40341, ...
# 11  [http://demo.fiz-karlsruhe.de/matwerk/E1198379...
# 12  [http://purls.helmholtz-metadaten.de/mwo/Elect...
# 13  [http://demo.fiz-karlsruhe.de/matwerk/E616496,...
# 14  [http://demo.fiz-karlsruhe.de/matwerk/E67431, ...
# 15  [http://demo.fiz-karlsruhe.de/matwerk/E444212,...
# 16  [http://demo.fiz-karlsruhe.de/matwerk/E1247883...
# 17  [http://purl.obolibrary.org/obo/NCIT_C93495, h...
# 18  [http://purl.obolibrary.org/obo/NCIT_C93495, h...
# 19  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 20  [http://demo.fiz-karlsruhe.de/matwerk/E547536,...
# 21  [http://nfdi.fiz-karlsruhe.de/ontology/Specifi...
# 22  [http://demo.fiz-karlsruhe.de/matwerk/E1146342...
# 23  [http://demo.fiz-karlsruhe.de/matwerk/E748254,...
# 24  [http://demo.fiz-karlsruhe.de/matwerk/E1027029...
# 25  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...
# 26  [http://demo.fiz-karlsruhe.de/matwerk/E52682, ...
# 27  [http://demo.fiz-karlsruhe.de/matwerk/E625404,...
# 28  [http://demo.fiz-karlsruhe.de/matwerk/E1247418...
# 29  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 30  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 31  [http://demo.fiz-karlsruhe.de/matwerk/E511556,...
# 32  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 33  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 34  [http://demo.fiz-karlsruhe.de/matwerk/E945626,...
# 35  [http://demo.fiz-karlsruhe.de/matwerk/E1213904...
# 36  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...

# %% [markdown]
# ## Find Most 7 Similarest Relations with Spacy and added "description"/"type"
# Our statistical results for similarity matching show that extracting the 7 most similar relations can cover the most exemplary question. Additionally, some answers to questions are included in the descriptive information, so such "mwo:description" and "dcterms:description" will be added.
#
# Here, SpaCy's en_core_web_lg model is efficient for relation matching, compare to BERT model.

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
def find_most_similar_relationships(df, relationship_column):
    # Load the spaCy English model
    nlp = spacy.load("en_core_web_lg")

    # Read data from an Excel file
    df_relationship = pd.read_excel('/content/extracted_relation_list.xlsx')

    # Convert the second column to lowercase and save it in a new column 'entity_lowercase'
    df_relationship['relationship_lowercase'] = df_relationship['Predicate readable'].str.lower()

    # Define a function to remove specific words and plural 's'
    def preprocess_text(text):
        # Remove specific words
        words_to_remove = {'has', 'is', 'of', 'in'}
        tokens = text.split()
        tokens = [word for word in tokens if word not in words_to_remove]

        # Remove trailing 's' for plurals
        processed_text = ' '.join(tokens)
        if processed_text.endswith('s'):
            processed_text = processed_text[:-1]

        return processed_text

    # Apply preprocessing to 'relationship_lowercase'
    df_relationship['cleaned_relationship'] = df_relationship['relationship_lowercase'].apply(preprocess_text)

    # Function to find most similar relationships
    def process_relationship(question_relationship):
        if not isinstance(question_relationship, str):
            return None, None, None

        question_word = nlp(preprocess_text(question_relationship.lower()))

        # Initialize a dictionary to store similarity scores
        similarity_scores = {}

        # Set a similarity threshold
        threshold = 0.6

        # Iterate through each word in the dataset and calculate its similarity to word1
        for index, row in df_relationship.iterrows():
            # Skip if the word is NaN
            if pd.isna(row['cleaned_relationship']):
                continue

            word2 = nlp(row['cleaned_relationship'])
            similarity = question_word.similarity(word2)
            similarity_scores[index] = similarity

            # Only store words with similarity scores above the threshold
            if similarity >= threshold:
                similarity_scores[index] = similarity

        # Find the top 9 highest similarity scores
        top_9_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:9]
        # For the Q3: Who is the email address of "ParaView"? , we have extracted the relation "email address"，
        # The right relation "mwo:hasContactPoint" is the 7th similaries relation

        # For the Q10: How should I cite pyiron?
        # The right relation "schema:citation" is the 9th similaries relation

        similar_relationships = []
        relationship_uris = []
        relationship_uris_withNS = []

        for index, similarity_score in top_9_similarities:
            if 0 <= index < len(df_relationship):
                similar_relationships.append(df_relationship.at[index, 'Predicate readable'])
                relationship_uris.append(df_relationship.at[index, 'Predicate_uri'])
                relationship_uris_withNS.append(df_relationship.at[index, 'Predicate with Namespace'])
        if 'mwo:description' not in relationship_uris_withNS:
          relationship_uris_withNS.append('mwo:description')
        if 'dcterms:description' not in relationship_uris_withNS:
          relationship_uris_withNS.append('dcterms:description')
        if 'rdf:type' not in relationship_uris_withNS:
          relationship_uris_withNS.append('rdf:type')

        return similar_relationships, relationship_uris, relationship_uris_withNS

    # Apply to each entity in the provided column of df
    results = df[relationship_column].apply(lambda x: process_relationship(x))
    df['Similar Relations'] = results.apply(lambda x: x[0] if x else None)
    df['Relation URIs'] = results.apply(lambda x: x[1] if x else None)
    df['Relation_uris_with_Namespace'] = results.apply(lambda x: x[2] if x else None)

    return df

df = pd.read_excel("SimilarEntities5+1.xlsx")
# Example usage with a DataFrame 'df' and a column 'Named Relationships'
df = find_most_similar_relationships(df, 'Predicate Verbs')

# To save the modified DataFrame:
df.to_excel("phrase_similarity5+1X9.xlsx", index=False)

df
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# <ipython-input-9-ca33ad38e492>:49: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = question_word.similarity(word2)
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6             Molecular Dynamics" Software?
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   ['computational materials science', 'Computati...
# 1   ['Elemental Multiperspective Material Ontology...
# 2   ['datasets', 'dataset', 'Image data', 'data po...
# 3   ['Ebrahim Norouzi', 'Ahmad Zainul Ihsan', 'Mir...
# 4   ['paraview', 'ParaView', 'data portal', 'datas...
# 5   ['Dr.  Volker Hofmann', 'Niklas Siemer', 'Dr. ...
# 6   ['Atomic Simulation Recipes', 'Workshop: From ...
# 7   ['Molecular Dynamics (MD)', 'Crystallography O...
# 8   ['computational materials science', 'Computati...
# 9   ['Pyiron', 'Pyrho', 'pyDOE', 'cython', 'Pyreti...
# 10  ['Analytic bond-order potentials', 'Mechanical...
# 11  ['Python scripts', 'Java', 'python', 'Python',...
# 12  ['electronic lab notebook', 'Jupyter notebooks...
# 13  ['molecular dynamics', 'Visual Molecular Dynam...
# 14  ['computational materials science', 'Computati...
# 15  ['Elk', 'NOMAD', 'Novel Materials Discovery (N...
# 16  ['Ontologies for Materials Science', 'Computat...
# 17  ['acronym', 'Silicon', 'SIRIUS', 'Crystallogra...
# 18  ['acronym', 'project', 'project', 'Project', '...
# 19  ['ontology', 'ontology matching', 'The MatWerk...
# 20  ['Materials Project API', 'HybriD³ materials d...
# 21  ['specification', 'Silicon', 'acronym', 'softw...
# 22  ['MatDB Online', 'MatDB', 'Organic Materials D...
# 23  ['Proprietary license', 'Proprietary commercia...
# 24  ['Materials Cloud', 'Materials Commons', 'Mate...
# 25  ['Bundesanstalt für Materialforschung und -prü...
# 26  ['Mechanics of Materials', 'mechanics of mater...
# 27  ['Transmission electron microscopy', 'X-ray mi...
# 28  ['Elastic Constant Demo Data', 'Elastic Consta...
# 29  ['hardness data', 'educational resource', 'Car...
# 30  ['hardness data', 'educational resource', 'Car...
# 31  ['pacemaker', 'Atomman', 'matador', 'Plant mov...
# 32  ['hardness data', 'educational resource', 'Car...
# 33  ['hardness data', 'educational resource', 'Car...
# 34  ['Bochkarev, A., Lysogorskiy, Y., Menon, S., Q...
# 35  ['hardness data', 'educational resource', 'Car...
# 36  ['Bundesanstalt für Materialforschung und -prü...
#
#                                           Entity URIs  \
# 0   ['http://demo.fiz-karlsruhe.de/matwerk/E67431'...
# 1   ['http://demo.fiz-karlsruhe.de/matwerk/E112675...
# 2   ['http://demo.fiz-karlsruhe.de/matwerk/E117221...
# 3   ['http://demo.fiz-karlsruhe.de/matwerk/E15879'...
# 4   ['http://demo.fiz-karlsruhe.de/matwerk/E123109...
# 5   ['http://demo.fiz-karlsruhe.de/matwerk/E9912',...
# 6   ['http://demo.fiz-karlsruhe.de/matwerk/E552776...
# 7   ['http://demo.fiz-karlsruhe.de/matwerk/E61379'...
# 8   ['http://demo.fiz-karlsruhe.de/matwerk/E67431'...
# 9   ['http://demo.fiz-karlsruhe.de/matwerk/E457491...
# 10  ['http://demo.fiz-karlsruhe.de/matwerk/E40341'...
# 11  ['http://demo.fiz-karlsruhe.de/matwerk/E119837...
# 12  ['http://purls.helmholtz-metadaten.de/mwo/Elec...
# 13  ['http://demo.fiz-karlsruhe.de/matwerk/E616496...
# 14  ['http://demo.fiz-karlsruhe.de/matwerk/E67431'...
# 15  ['http://demo.fiz-karlsruhe.de/matwerk/E444212...
# 16  ['http://demo.fiz-karlsruhe.de/matwerk/E124788...
# 17  ['http://purl.obolibrary.org/obo/NCIT_C93495',...
# 18  ['http://purl.obolibrary.org/obo/NCIT_C93495',...
# 19  ['https://nfdi.fiz-karlsruhe.de/ontology/Ontol...
# 20  ['http://demo.fiz-karlsruhe.de/matwerk/E547536...
# 21  ['http://nfdi.fiz-karlsruhe.de/ontology/Specif...
# 22  ['http://demo.fiz-karlsruhe.de/matwerk/E114634...
# 23  ['http://demo.fiz-karlsruhe.de/matwerk/E748254...
# 24  ['http://demo.fiz-karlsruhe.de/matwerk/E102702...
# 25  ['http://demo.fiz-karlsruhe.de/matwerk/E124796...
# 26  ['http://demo.fiz-karlsruhe.de/matwerk/E52682'...
# 27  ['http://demo.fiz-karlsruhe.de/matwerk/E625404...
# 28  ['http://demo.fiz-karlsruhe.de/matwerk/E124741...
# 29  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 30  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 31  ['http://demo.fiz-karlsruhe.de/matwerk/E511556...
# 32  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 33  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 34  ['http://demo.fiz-karlsruhe.de/matwerk/E945626...
# 35  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 36  ['http://demo.fiz-karlsruhe.de/matwerk/E124796...
#
#                                     Similar Relations  \
# 0   [has work package, has expertise in, has fundi...
# 1   [has related Project, related participant proj...
# 2   [has contributor, related participant project ...
# 3   [has work package, has expertise in, has fundi...
# 4   [has email address , has postal address, has w...
# 5   [has affiliation, has curation status, has par...
# 6   [has documentation, has bibliographic citation...
# 7   [required tool, has related resource, related ...
# 8   [has some values from, has work package, has r...
# 9   [has annotated source , has bibliographic cita...
# 10  [has  description, has description, has biblio...
# 11  [uses software, has example of usage, has repo...
# 12  [has type, has object type, has media type or ...
# 13  [uses software, required tool, has operating s...
# 14  [has bibliographic citation, has  description,...
# 15  [has type, has object type, has media type or ...
# 16  [has repository, has website, has definition s...
# 17  [has instrument model, has first element, has ...
# 18  [has  description, has description, has biblio...
# 19  [has related resource, related participant pro...
# 20  [has url, has file Extension, has repository, ...
# 21  [has  description, has description, has biblio...
# 22  [has documentation, has bibliographic citation...
# 23  [has type, has object type, has media type or ...
# 24  [has conforms to specification, belongs to, re...
# 25  [has definition source, has annotated source ,...
# 26  [has some values from, has related resource, a...
# 27  [has related resource, related participant pro...
# 28  [has license, has license, has affiliation, ha...
# 29  [has repository, has annotated source , has de...
# 30  [has format, has format, has documentation, ha...
# 31  [has Version, uses software, has instrument mo...
# 32  [has related task area, has discipline, has ma...
# 33  [has  description, has description, has biblio...
# 34  [has definition source, has annotated source ,...
# 35  [has creator, has author, has contributor, use...
# 36  [has repository, has bibliographic citation, h...
#
#                                         Relation URIs  \
# 0   [https://nfdi.fiz-karlsruhe.de/ontology/exampl...
# 1   [https://schema.org/dateCreated, http://nfdi.f...
# 2   [http://www.geneontology.org/formats/oboInOwl#...
# 3   [https://nfdi.fiz-karlsruhe.de/ontology/exampl...
# 4   [http://purl.obolibrary.org/obo/IAO_0000119, h...
# 5   [http://purls.helmholtz-metadaten.de/mwo/isOnl...
# 6   [https://w3id.org/scholarlydata/ontology/confe...
# 7   [http://purls.helmholtz-metadaten.de/mwo/hasWe...
# 8   [http://purls.helmholtz-metadaten.de/mwo/hasWo...
# 9   [http://emmo.info/emmo#EMMO_967080e5_2f42_4eb2...
# 10  [http://purl.obolibrary.org/obo/IAO_0000115, h...
# 11  [http://purls.helmholtz-metadaten.de/mwo/hasCo...
# 12  [http://purl.obolibrary.org/obo/IAO_0000111, h...
# 13  [http://purls.helmholtz-metadaten.de/mwo/hasCo...
# 14  [http://www.w3.org/2002/07/owl#sameAs, http://...
# 15  [http://purl.obolibrary.org/obo/IAO_0000111, h...
# 16  [http://purls.helmholtz-metadaten.de/mwo/usesT...
# 17  [http://www.w3.org/2004/02/skos/core#prefLabel...
# 18  [http://purl.obolibrary.org/obo/IAO_0000115, h...
# 19  [http://purls.helmholtz-metadaten.de/mwo/hasLe...
# 20  [http://purls.helmholtz-metadaten.de/mwo/hasRO...
# 21  [http://purl.obolibrary.org/obo/IAO_0000115, h...
# 22  [https://w3id.org/scholarlydata/ontology/confe...
# 23  [http://purl.obolibrary.org/obo/IAO_0000111, h...
# 24  [http://purls.helmholtz-metadaten.de/mwo/hasFo...
# 25  [http://purls.helmholtz-metadaten.de/mwo/hasCo...
# 26  [http://purls.helmholtz-metadaten.de/mwo/hasWo...
# 27  [http://purls.helmholtz-metadaten.de/mwo/hasLe...
# 28  [http://purl.org/dc/terms/format, http://www.w...
# 29  [http://purls.helmholtz-metadaten.de/mwo/usesT...
# 30  [http://www.ebi.ac.uk/swo/has_license, http://...
# 31  [http://purls.helmholtz-metadaten.de/mwo/keywo...
# 32  [http://purls.helmholtz-metadaten.de/mwo/belon...
# 33  [http://purl.obolibrary.org/obo/IAO_0000115, h...
# 34  [http://purls.helmholtz-metadaten.de/mwo/hasCo...
# 35  [http://purls.helmholtz-metadaten.de/mwo/hasAf...
# 36  [http://purls.helmholtz-metadaten.de/mwo/usesT...
#
#                          Relation_uris_with_Namespace
# 0   [mwo:hasWorkPackage, mwo:hasExpertiseIn, nfdic...
# 1   [nfdicore:relatedProject, mwo:relatedParticipa...
# 2   [mwo:hasContributor, mwo:relatedParticipantPro...
# 3   [mwo:hasWorkPackage, mwo:hasExpertiseIn, nfdic...
# 4   [mwo:emailAddress, mwo:hasPostalAddress, mwo:h...
# 5   [mwo:hasAffiliation, ns2:IAO_0000114, nfdicore...
# 6   [mwo:hasDocumentation, dcterms:bibliographicCi...
# 7   [mwo:requiredTool, mwo:hasRelatedResource, mwo...
# 8   [owl:someValuesFrom, mwo:hasWorkPackage, mwo:h...
# 9   [owl:annotatedSource, dcterms:bibliographicCit...
# 10  [dcterms:description, mwo:description, dcterms...
# 11  [ns3:SWO_0000082, ns2:IAO_0000112, mwo:hasRepo...
# 12  [rdf:type, nfdicore:objectType, dc:contributor...
# 13  [ns3:SWO_0000082, mwo:requiredTool, schema:ope...
# 14  [dcterms:bibliographicCitation, dcterms:descri...
# 15  [rdf:type, nfdicore:objectType, dc:contributor...
# 16  [mwo:hasRepository, mwo:hasWebsite, ns2:IAO_00...
# 17  [mwo:instrumentModel, rdf:first, mwo:hasDocume...
# 18  [dcterms:description, mwo:description, dcterms...
# 19  [mwo:hasRelatedResource, mwo:relatedParticipan...
# 20  [nfdicore:url, nfdicore:fileExtension, mwo:has...
# 21  [dcterms:description, mwo:description, dcterms...
# 22  [mwo:hasDocumentation, dcterms:bibliographicCi...
# 23  [rdf:type, nfdicore:objectType, dc:contributor...
# 24  [mwo:conformsToSpecification, mwo:belongsTo, m...
# 25  [ns2:IAO_0000119, owl:annotatedSource, mwo:rel...
# 26  [owl:someValuesFrom, mwo:hasRelatedResource, o...
# 27  [mwo:hasRelatedResource, mwo:relatedParticipan...
# 28  [dcterms:license, ns3:has_license, mwo:hasAffi...
# 29  [mwo:hasRepository, owl:annotatedSource, ns2:I...
# 30  [dcterms:format, mwo:hasFormat, mwo:hasDocumen...
# 31  [mwo:hasVersion, ns3:SWO_0000082, mwo:instrume...
# 32  [mwo:relatedTaskArea, mwo:hasDiscipline, mwo:m...
# 33  [dcterms:description, mwo:description, dcterms...
# 34  [ns2:IAO_0000119, owl:annotatedSource, mwo:rel...
# 35  [mwo:hasCreator, mwo:hasAuthor, mwo:hasContrib...
# 36  [mwo:hasRepository, dcterms:bibliographicCitat...

# %% [markdown]
# ## Sentence Similarity between the given question and descriptions
# We find that the interval descriptions could contain some answers to a certain question, so we do sentence similarity matching between the given question and interval description to find the most N similar entities, wich contain relevant information. It is not easy to find correcet N, because the similarity is easiliy effect by the

# %%
# texts which actually contain relevant information in description
texts = [
    'What is "Molecular Dynamics" Software? List the programming language, documentation page, repository, and license information.', #Q7
    'What are pre- and post-processing tools for MD simulations?', #Q8
    'What are some workflow environments for computational materials science?', #Q9
    'Where can I find a list of interatomic potentials?', #Q11
    'What are python libraries used for calculating local atomic structural environment?', #Q12
    'What are the electronic lab notebooks available?', #Q13
    'What are the software for Molecular Dynamics (MD)?', #Q14
    'What are the ontologies in nanomaterials domain?', #Q15
    'What is DAMASK?', #Q16
    'What are the data portals for materials science ontologies?',#Q17
    'What are the instruments for APT?', #Q18
    'In which institution can I find tomography equipment?',#Q19
    'What are the educational resources for Ontology?',
    'What is the API of Materials Project?',
    'Which simulation software have a python API?',
    'What is the documentation of the "MatDB Online"?',
    'What are the types of software licenses?',
    'What are the software used to produce the data in the Materials Cloud repository?',
    'What are datasets produced by the BAM organization?',
    'What are some available datasets of mechanical properties of steels?',
    'What are datasets related to "Transmission electron microscopy"?',
    'What is the license of the dataset "Elastic Constant Demo Data"?',
    'What is the repository for "BAM reference data"?',
    'What are the different data formats in the "BAM reference data"?',
    'What is the software version of "pacemaker"?',
    'What is the field of research "BAM reference data"?',
    'What is the description of the "BAM reference data"?',
    'What are the datasets produced in 2022?',
    'Who are the creators of the "BAM reference data"?',
    'What are the datasets published by "BAM"?'

]

# %%
import pandas as pd
from transformers import BertTokenizer, BertModel
import torch
from scipy.spatial.distance import cosine

# Load your DataFrame
df_des = pd.read_excel(('/content/extracted_headentity_list.xlsx'))

# Function to load the model and tokenizer
def get_model_and_tokenizer(model_name="bert-base-uncased"):
    tokenizer = BertTokenizer.from_pretrained(model_name)
    model = BertModel.from_pretrained(model_name)
    return model, tokenizer

# Function to encode a sentence
def encode_sentence(sentence, model, tokenizer):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1)

# Function to compare two sentences
def compare_sentences(sentence1, sentence2, model, tokenizer):
    embedding1 = encode_sentence(sentence1, model, tokenizer)
    embedding2 = encode_sentence(sentence2, model, tokenizer)
    similarity = 1 - cosine(embedding1[0].numpy(), embedding2[0].numpy())
    return similarity

# Load the pre-trained model and tokenizer
model, tokenizer = get_model_and_tokenizer()

# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=["Text", "Similar Entities", "Entity URIs", "Similarities"])
threshold = 0.7  # Define the similarity score threshold

# For each sentence in texts
for sentence1 in texts:
    similarities = []
    # Compute similarity with each sentence in df_des
    for idx, row in df_des.iterrows():
        sentence2 = str(row["entity_description"])  # Ensure sentence2 is a string
        similarity = compare_sentences(sentence1, sentence2, model, tokenizer)
        if similarity > threshold:  # Only consider similarities above the threshold
            similarities.append((similarity, idx))

    # Continue only if there are similarities above the threshold
    if similarities:
        # Sort indices by similarity and select top results
        top_indices = sorted(similarities, key=lambda x: x[0], reverse=True)[:8]

        # Extract similar entities, their URIs, and similarities
        similar_entities = [df_des.iloc[idx]["entity_label"] for _, idx in top_indices]
        entity_uris = [df_des.iloc[idx]["entity_uri"] for _, idx in top_indices]
        similarity_scores = [sim[0] for sim in top_indices]

        # Add to the results DataFrame
        results_df = pd.concat([results_df, pd.DataFrame({"Text": [sentence1],
                                                          "Similar Entities": [similar_entities],
                                                          "Entity URIs": [entity_uris],
                                                          "Similarities": [similarity_scores]})], ignore_index=True)

# To save the modified DataFrame:
results_df.to_excel("sentence_similarity.xlsx", index=False)

# Print out the sentences with their similarities above the threshold
for index, row in results_df.iterrows():
    print(f"Text: {row['Text']}")
    for i, (entity, uri, similarity) in enumerate(zip(row['Similar Entities'], row['Entity URIs'], row['Similarities'])):
        print(f"{i+1}. Entity: {entity}, URI: {uri}, Similarity: {similarity}")
    print("\n")
# Out:
# Text: Who is working in the Computational Materials Science field?
# 1. Entity: Materials Design Ontology (MDO), URI: http://demo.fiz-karlsruhe.de/matwerk/E1131257, Similarity: 0.7672711610794067
# 2. Entity: Open Materials Database, URI: http://demo.fiz-karlsruhe.de/matwerk/E643412, Similarity: 0.7573269009590149
# 3. Entity: Pyiron YouTube channel, URI: http://demo.fiz-karlsruhe.de/matwerk/E1245283, Similarity: 0.7545511722564697
# 4. Entity: MaterialsProject, URI: http://demo.fiz-karlsruhe.de/matwerk/E1025597, Similarity: 0.7534968256950378
# 5. Entity: MaterialsMine (MM), URI: http://demo.fiz-karlsruhe.de/matwerk/E1128252, Similarity: 0.7513790726661682
# 6. Entity: Thermo-Calc, URI: http://demo.fiz-karlsruhe.de/matwerk/E451776, Similarity: 0.751322865486145
# 7. Entity: Avogadro, URI: http://demo.fiz-karlsruhe.de/matwerk/E472907, Similarity: 0.743194580078125
# 8. Entity: Polymer Genome, URI: http://demo.fiz-karlsruhe.de/matwerk/E1066071, Similarity: 0.7423355579376221
#
#
# Text: Who are the contributors of the data "datasets"?
# 1. Entity: has creator, URI: http://purls.helmholtz-metadaten.de/mwo/hasCreator, Similarity: 0.776042640209198
# 2. Entity: resource, URI: http://nfdi.fiz-karlsruhe.de/ontology/Resource, Similarity: 0.7632700204849243
# 3. Entity: about material, URI: http://purls.helmholtz-metadaten.de/mwo/aboutMaterial, Similarity: 0.7532092332839966
# 4. Entity: has personal information, URI: http://purls.helmholtz-metadaten.de/mwo/hasPersonalInformation, Similarity: 0.7493810653686523
# 5. Entity: Phonon database at Kyoto university, URI: http://demo.fiz-karlsruhe.de/matwerk/E1074846, Similarity: 0.7367544770240784
# 6. Entity: dateCreated, URI: https://schema.org/dateCreated, Similarity: 0.7359830141067505
# 7. Entity: UDC, URI: http://purl.org/dc/elements/1.1/contributor, Similarity: 0.7350300550460815
# 8. Entity: semantic resource, URI: http://purls.helmholtz-metadaten.de/mwo/SemanticResource, Similarity: 0.7347659468650818
#
#
# Text: Who is working with Researcher "Ebrahim Norouzi" in the same group?
# 1. Entity: Phonon database at Kyoto university, URI: http://demo.fiz-karlsruhe.de/matwerk/E1074846, Similarity: 0.7229446768760681
#
#
# Text: Who is the email address of "ParaView"?
# 1. Entity: dateCreated, URI: https://schema.org/dateCreated, Similarity: 0.7022454142570496
#
#
# Text: What is "Molecular Dynamics" Software? List the programming language, documentation page, repository, and license information.
# 1. Entity: Computational Materials Repository (CMR), URI: http://demo.fiz-karlsruhe.de/matwerk/E1060241, Similarity: 0.8298475742340088
# 2. Entity: PubChem, URI: http://demo.fiz-karlsruhe.de/matwerk/E1021307, Similarity: 0.8252118825912476
# 3. Entity: OpenBIS, URI: http://demo.fiz-karlsruhe.de/matwerk/E551726, Similarity: 0.821381688117981
# 4. Entity: controlled vocabulary, URI: https://nfdi.fiz-karlsruhe.de/ontology/ControlledVocabulary, Similarity: 0.8069674372673035
# 5. Entity: controlled vocabulary, URI: http://nfdi.fiz-karlsruhe.de/ontology/ControlledVocabulary, Similarity: 0.8069674372673035
# 6. Entity: Cluster Expansion in Atomic Simulation Environment, URI: http://demo.fiz-karlsruhe.de/matwerk/E488579, Similarity: 0.8058927059173584
# 7. Entity: Physical Information File (PIF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1158482, Similarity: 0.8053192496299744
# 8. Entity: Graphical Interface for Materials Simulations, URI: http://demo.fiz-karlsruhe.de/matwerk/E469997, Similarity: 0.8037340044975281
#
#
# Text: What are pre- and post-processing tools for MD simulations?
# 1. Entity: OVITO basic, URI: http://demo.fiz-karlsruhe.de/matwerk/E461321, Similarity: 0.8328317403793335
# 2. Entity: AML, URI: http://demo.fiz-karlsruhe.de/matwerk/E473879, Similarity: 0.8171682953834534
# 3. Entity: MDTraj, URI: http://demo.fiz-karlsruhe.de/matwerk/E482672, Similarity: 0.8128783106803894
# 4. Entity: Extensible Self-optimizing Phase Equilibria Infrastructure, URI: http://demo.fiz-karlsruhe.de/matwerk/E491546, Similarity: 0.8060132265090942
# 5. Entity: Pizza.py Toolkit, URI: http://demo.fiz-karlsruhe.de/matwerk/E481691, Similarity: 0.801620364189148
# 6. Entity: Yet another force field, URI: http://demo.fiz-karlsruhe.de/matwerk/E487592, Similarity: 0.801141619682312
# 7. Entity: Graphical Interface for Materials Simulations, URI: http://demo.fiz-karlsruhe.de/matwerk/E469997, Similarity: 0.7979493737220764
# 8. Entity: freud, URI: http://demo.fiz-karlsruhe.de/matwerk/E483654, Similarity: 0.797276496887207
#
#
# Text: What are some workflow environments for computational materials science?
# 1. Entity: Simmate, URI: http://demo.fiz-karlsruhe.de/matwerk/E594506, Similarity: 0.7957922220230103
# 2. Entity: matminer, URI: http://demo.fiz-karlsruhe.de/matwerk/E497507, Similarity: 0.7936322093009949
# 3. Entity: Pyiron, URI: http://demo.fiz-karlsruhe.de/matwerk/E457491, Similarity: 0.790785014629364
# 4. Entity: The Materials Data Facility (MDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1067531, Similarity: 0.7818992137908936
# 5. Entity: freud, URI: http://demo.fiz-karlsruhe.de/matwerk/E483654, Similarity: 0.7811697721481323
# 6. Entity: pycalphad, URI: http://demo.fiz-karlsruhe.de/matwerk/E492537, Similarity: 0.7809754014015198
# 7. Entity: MGI JSON Schema, URI: http://demo.fiz-karlsruhe.de/matwerk/E1161527, Similarity: 0.7783390879631042
# 8. Entity: Polymer Genome, URI: http://demo.fiz-karlsruhe.de/matwerk/E1066071, Similarity: 0.7738624215126038
#
#
# Text: Where can I find a list of interatomic potentials?
# 1. Entity: potentials repository, URI: http://purls.helmholtz-metadaten.de/mwo/PotentialsRepository, Similarity: 0.7681039571762085
# 2. Entity: Interatomic potentials repository (NIST), URI: http://demo.fiz-karlsruhe.de/matwerk/E1014177, Similarity: 0.7256261706352234
# 3. Entity: Workshop: Workflows for atomistic simulations, URI: http://demo.fiz-karlsruhe.de/matwerk/E1245321, Similarity: 0.7220953106880188
# 4. Entity: mendeleev, URI: http://demo.fiz-karlsruhe.de/matwerk/E499502, Similarity: 0.7209247350692749
# 5. Entity: The Science Hub for Atomic-scale Research at Chalmers, URI: http://demo.fiz-karlsruhe.de/matwerk/E506516, Similarity: 0.7206828594207764
# 6. Entity: The ITAP Molecular Dynamics Program, URI: http://demo.fiz-karlsruhe.de/matwerk/E448932, Similarity: 0.7164483666419983
# 7. Entity: pacemaker, URI: http://demo.fiz-karlsruhe.de/matwerk/E511556, Similarity: 0.7156273722648621
# 8. Entity: NGLview, URI: http://demo.fiz-karlsruhe.de/matwerk/E484637, Similarity: 0.7140293717384338
#
#
# Text: What are python libraries used for calculating local atomic structural environment?
# 1. Entity: Pyscal, URI: http://demo.fiz-karlsruhe.de/matwerk/E413687, Similarity: 0.8711915016174316
# 2. Entity: matminer, URI: http://demo.fiz-karlsruhe.de/matwerk/E497507, Similarity: 0.8447264432907104
# 3. Entity: icet, URI: http://demo.fiz-karlsruhe.de/matwerk/E489567, Similarity: 0.8380201458930969
# 4. Entity: Calphy, URI: http://demo.fiz-karlsruhe.de/matwerk/E411872, Similarity: 0.8359113335609436
# 5. Entity: py4vasp, URI: http://demo.fiz-karlsruhe.de/matwerk/E466131, Similarity: 0.8299081325531006
# 6. Entity: OpenPathSampling, URI: http://demo.fiz-karlsruhe.de/matwerk/E476801, Similarity: 0.810386061668396
# 7. Entity: EQ2PC, URI: http://demo.fiz-karlsruhe.de/matwerk/E414596, Similarity: 0.8057491779327393
# 8. Entity: Cluster Expansion in Atomic Simulation Environment, URI: http://demo.fiz-karlsruhe.de/matwerk/E488579, Similarity: 0.8029974102973938
#
#
# Text: What are the software for Molecular Dynamics (MD)?
# 1. Entity: Yet another force field, URI: http://demo.fiz-karlsruhe.de/matwerk/E487592, Similarity: 0.7991178035736084
# 2. Entity: dynasor, URI: http://demo.fiz-karlsruhe.de/matwerk/E505511, Similarity: 0.7940085530281067
# 3. Entity: QuickFF, URI: http://demo.fiz-karlsruhe.de/matwerk/E485621, Similarity: 0.7907077074050903
# 4. Entity: freud, URI: http://demo.fiz-karlsruhe.de/matwerk/E483654, Similarity: 0.7775577306747437
# 5. Entity: matminer, URI: http://demo.fiz-karlsruhe.de/matwerk/E497507, Similarity: 0.773648738861084
# 6. Entity: Simmate, URI: http://demo.fiz-karlsruhe.de/matwerk/E594506, Similarity: 0.7698553800582886
# 7. Entity: Vienna Ab initio Simulation Package, URI: http://demo.fiz-karlsruhe.de/matwerk/E425582, Similarity: 0.7695932984352112
# 8. Entity: FitSNAP, URI: http://demo.fiz-karlsruhe.de/matwerk/E496511, Similarity: 0.7644413709640503
#
#
# Text: What are the ontologies in nanomaterials domain?
# 1. Entity: MaterialsMine (MM), URI: http://demo.fiz-karlsruhe.de/matwerk/E1128252, Similarity: 0.8046297430992126
# 2. Entity: Materials Design Ontology (MDO), URI: http://demo.fiz-karlsruhe.de/matwerk/E1131257, Similarity: 0.803712785243988
# 3. Entity: Materials And Molecules Basic Ontology (MAMBO), URI: http://demo.fiz-karlsruhe.de/matwerk/E1143317, Similarity: 0.7940781712532043
# 4. Entity: eNanoMapper ontology, URI: http://demo.fiz-karlsruhe.de/matwerk/E1137279, Similarity: 0.7811478972434998
# 5. Entity: Knowledge Graphs (openHPI Massive Open Online Course (MOOC)), URI: http://demo.fiz-karlsruhe.de/matwerk/E1245261, Similarity: 0.7700950503349304
# 6. Entity: Essential Source of Schemas and Examples (ESSE), URI: http://demo.fiz-karlsruhe.de/matwerk/E1152404, Similarity: 0.7690978050231934
# 7. Entity: SimPhoNy, URI: http://demo.fiz-karlsruhe.de/matwerk/E514592, Similarity: 0.7644919753074646
# 8. Entity: Computational Material Sample Ontology, URI: http://demo.fiz-karlsruhe.de/matwerk/E1247323, Similarity: 0.7625333070755005
#
#
# Text: What are the data portals for materials science ontologies?
# 1. Entity: MatPortal, URI: http://demo.fiz-karlsruhe.de/matwerk/E1029896, Similarity: 0.7930157780647278
# 2. Entity: Materials Design Ontology (MDO), URI: http://demo.fiz-karlsruhe.de/matwerk/E1131257, Similarity: 0.7827779054641724
# 3. Entity: MaterialsMine (MM), URI: http://demo.fiz-karlsruhe.de/matwerk/E1128252, Similarity: 0.7778983116149902
# 4. Entity: Essential Source of Schemas and Examples (ESSE), URI: http://demo.fiz-karlsruhe.de/matwerk/E1152404, Similarity: 0.7757351994514465
# 5. Entity: materials database, URI: http://purls.helmholtz-metadaten.de/mwo/MaterialsDatabase, Similarity: 0.7735152840614319
# 6. Entity: MGI JSON Schema, URI: http://demo.fiz-karlsruhe.de/matwerk/E1161527, Similarity: 0.7653436660766602
# 7. Entity: Materials And Molecules Basic Ontology (MAMBO), URI: http://demo.fiz-karlsruhe.de/matwerk/E1143317, Similarity: 0.7643849849700928
# 8. Entity: Simmate, URI: http://demo.fiz-karlsruhe.de/matwerk/E594506, Similarity: 0.7629305124282837
#
#
# Text: What are the educational resources for Ontology?
# 1. Entity: glossary, URI: http://nfdi.fiz-karlsruhe.de/ontology/Glossary, Similarity: 0.7161356806755066
# 2. Entity: glossary, URI: https://nfdi.fiz-karlsruhe.de/ontology/Glossary, Similarity: 0.7161356806755066
# 3. Entity: MatPortal, URI: http://demo.fiz-karlsruhe.de/matwerk/E1029896, Similarity: 0.7103961110115051
#
#
# Text: What is the API of Materials Project?
# 1. Entity: Python Materials Genomics, URI: http://demo.fiz-karlsruhe.de/matwerk/E478754, Similarity: 0.7113269567489624
#
#
# Text: Which simulation software have a python API?
# 1. Entity: OpenPathSampling, URI: http://demo.fiz-karlsruhe.de/matwerk/E476801, Similarity: 0.7834775447845459
# 2. Entity: py4vasp, URI: http://demo.fiz-karlsruhe.de/matwerk/E466131, Similarity: 0.7825597524642944
# 3. Entity: CompositionSpace, URI: http://demo.fiz-karlsruhe.de/matwerk/E1246567, Similarity: 0.7701759338378906
# 4. Entity: Pyscal, URI: http://demo.fiz-karlsruhe.de/matwerk/E413687, Similarity: 0.7567362189292908
# 5. Entity: programming language, URI: http://nfdi.fiz-karlsruhe.de/ontology/ProgrammingLanguage, Similarity: 0.7514336109161377
# 6. Entity: pycp2k, URI: http://demo.fiz-karlsruhe.de/matwerk/E474852, Similarity: 0.7503904104232788
# 7. Entity: matminer, URI: http://demo.fiz-karlsruhe.de/matwerk/E497507, Similarity: 0.7481774091720581
# 8. Entity: icet, URI: http://demo.fiz-karlsruhe.de/matwerk/E489567, Similarity: 0.7478575706481934
#
#
# Text: What is the documentation of the "MatDB Online"?
# 1. Entity: NOMAD Metainfo, URI: http://demo.fiz-karlsruhe.de/matwerk/E1156961, Similarity: 0.749140739440918
# 2. Entity: Materials Platform for Data Science, URI: http://demo.fiz-karlsruhe.de/matwerk/E1035642, Similarity: 0.741711437702179
# 3. Entity: Materials Data Repository, URI: http://demo.fiz-karlsruhe.de/matwerk/E1042847, Similarity: 0.728651225566864
# 4. Entity: Phonon database at Kyoto university, URI: http://demo.fiz-karlsruhe.de/matwerk/E1074846, Similarity: 0.7238051891326904
# 5. Entity: Metadata schemes for materials science data, URI: http://demo.fiz-karlsruhe.de/matwerk/E1123752, Similarity: 0.7219794988632202
# 6. Entity: Workshop: Simulation workflows in materials modelling, URI: http://demo.fiz-karlsruhe.de/matwerk/E1245333, Similarity: 0.7191509008407593
# 7. Entity: Electronic Structure Common Data Format (ESCDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1153922, Similarity: 0.7156352400779724
# 8. Entity: has repository, URI: http://purls.helmholtz-metadaten.de/mwo/hasRepository, Similarity: 0.7090325951576233
#
#
# Text: What are the types of software licenses?
# 1. Entity: has format, URI: http://purls.helmholtz-metadaten.de/mwo/hasFormat, Similarity: 0.7056126594543457
#
#
# Text: What are the software used to produce the data in the Materials Cloud repository?
# 1. Entity: Materials Data Repository, URI: http://demo.fiz-karlsruhe.de/matwerk/E1042847, Similarity: 0.7893213629722595
# 2. Entity: has repository, URI: http://purls.helmholtz-metadaten.de/mwo/hasRepository, Similarity: 0.7822422981262207
# 3. Entity: OpenBIS, URI: http://demo.fiz-karlsruhe.de/matwerk/E551726, Similarity: 0.7816780209541321
# 4. Entity: Khazana, URI: http://demo.fiz-karlsruhe.de/matwerk/E1064612, Similarity: 0.7805479168891907
# 5. Entity: Computational Materials Repository (CMR), URI: http://demo.fiz-karlsruhe.de/matwerk/E1060241, Similarity: 0.769416868686676
# 6. Entity: The MatWerk ontology, URI: http://purls.helmholtz-metadaten.de/mwo/, Similarity: 0.7686192989349365
# 7. Entity: NOMAD Metainfo, URI: http://demo.fiz-karlsruhe.de/matwerk/E1156961, Similarity: 0.767957866191864
# 8. Entity: Electronic Structure Common Data Format (ESCDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1153922, Similarity: 0.7674663066864014
#
#
# Text: What are datasets produced by the BAM organization?
# 1. Entity: NOMAD Metainfo, URI: http://demo.fiz-karlsruhe.de/matwerk/E1156961, Similarity: 0.7455052733421326
# 2. Entity: has creator, URI: http://purls.helmholtz-metadaten.de/mwo/hasCreator, Similarity: 0.7418684363365173
# 3. Entity: about material, URI: http://purls.helmholtz-metadaten.de/mwo/aboutMaterial, Similarity: 0.7250615358352661
# 4. Entity: provided resource, URI: http://nfdi.fiz-karlsruhe.de/ontology/ProvidedResource, Similarity: 0.7229470014572144
# 5. Entity: Electronic Structure Common Data Format (ESCDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1153922, Similarity: 0.722618818283081
# 6. Entity: The Materials Data Facility (MDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1067531, Similarity: 0.715350329875946
# 7. Entity: Computational Materials Repository (CMR), URI: http://demo.fiz-karlsruhe.de/matwerk/E1060241, Similarity: 0.7139847874641418
# 8. Entity: data portal, URI: http://nfdi.fiz-karlsruhe.de/ontology/DataPortal, Similarity: 0.7137879133224487
#
#
# Text: What are some available datasets of mechanical properties of steels?
# 1. Entity: Elastic Constant Demo Data, URI: http://demo.fiz-karlsruhe.de/matwerk/E1247418, Similarity: 0.836538553237915
# 2. Entity: MatDat, URI: http://demo.fiz-karlsruhe.de/matwerk/E1041404, Similarity: 0.8124992847442627
# 3. Entity: Polymer Database (PoLyInfo), URI: http://demo.fiz-karlsruhe.de/matwerk/E1045736, Similarity: 0.7976945638656616
# 4. Entity: materials database, URI: http://purls.helmholtz-metadaten.de/mwo/MaterialsDatabase, Similarity: 0.7934147715568542
# 5. Entity: Elastic Constant Demo, URI: http://demo.fiz-karlsruhe.de/matwerk/E1246648, Similarity: 0.7898780703544617
# 6. Entity: Diffusion Database (Kakusan), URI: http://demo.fiz-karlsruhe.de/matwerk/E1050077, Similarity: 0.7872816324234009
# 7. Entity: Inorganic Material Database (AtomWork), URI: http://demo.fiz-karlsruhe.de/matwerk/E1047182, Similarity: 0.7790257334709167
# 8. Entity: Atomic Simulation Recipes, URI: http://demo.fiz-karlsruhe.de/matwerk/E552776, Similarity: 0.7780264616012573
#
#
# Text: What are datasets related to "Transmission electron microscopy"?
# 1. Entity: materials database, URI: http://purls.helmholtz-metadaten.de/mwo/MaterialsDatabase, Similarity: 0.7953129410743713
# 2. Entity: Atomic Simulation Recipes, URI: http://demo.fiz-karlsruhe.de/matwerk/E552776, Similarity: 0.7883117198944092
# 3. Entity: pySTEM, URI: http://demo.fiz-karlsruhe.de/matwerk/E522732, Similarity: 0.7878686189651489
# 4. Entity: Soprano, URI: http://demo.fiz-karlsruhe.de/matwerk/E468062, Similarity: 0.7876636981964111
# 5. Entity: Material Properties Open Database (MPOD), URI: http://demo.fiz-karlsruhe.de/matwerk/E1068992, Similarity: 0.7876405119895935
# 6. Entity: pyXIT, URI: http://demo.fiz-karlsruhe.de/matwerk/E420987, Similarity: 0.7821601033210754
# 7. Entity: Thermo-Calc, URI: http://demo.fiz-karlsruhe.de/matwerk/E451776, Similarity: 0.7815392017364502
# 8. Entity: Computational Material Sample Ontology, URI: http://demo.fiz-karlsruhe.de/matwerk/E1247323, Similarity: 0.7802723050117493
#
#
# Text: What is the license of the dataset "Elastic Constant Demo Data"?
# 1. Entity: Metadata schemes for materials science data, URI: http://demo.fiz-karlsruhe.de/matwerk/E1123752, Similarity: 0.7731269598007202
# 2. Entity: Phonon database at Kyoto university, URI: http://demo.fiz-karlsruhe.de/matwerk/E1074846, Similarity: 0.766732931137085
# 3. Entity: semantic expressivity, URI: http://nfdi.fiz-karlsruhe.de/ontology/SemanticExpressivity, Similarity: 0.7635065913200378
# 4. Entity: has repository, URI: http://purls.helmholtz-metadaten.de/mwo/hasRepository, Similarity: 0.7619881629943848
# 5. Entity: Fiji, URI: http://demo.fiz-karlsruhe.de/matwerk/E422822, Similarity: 0.759754478931427
# 6. Entity: Electronic Structure Common Data Format (ESCDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1153922, Similarity: 0.7517324090003967
# 7. Entity: UDC, URI: http://purl.org/dc/elements/1.1/contributor, Similarity: 0.750860869884491
# 8. Entity: TEMMETA, URI: http://demo.fiz-karlsruhe.de/matwerk/E500501, Similarity: 0.7507756948471069
#
#
# Text: What is the repository for "BAM reference data"?
# 1. Entity: has repository, URI: http://purls.helmholtz-metadaten.de/mwo/hasRepository, Similarity: 0.7522176504135132
# 2. Entity: about material, URI: http://purls.helmholtz-metadaten.de/mwo/aboutMaterial, Similarity: 0.7383511066436768
# 3. Entity: UDC, URI: http://purl.org/dc/elements/1.1/contributor, Similarity: 0.7357584834098816
# 4. Entity: provided resource, URI: http://nfdi.fiz-karlsruhe.de/ontology/ProvidedResource, Similarity: 0.7343433499336243
# 5. Entity: NOMAD Metainfo, URI: http://demo.fiz-karlsruhe.de/matwerk/E1156961, Similarity: 0.7314974069595337
# 6. Entity: object type, URI: http://nfdi.fiz-karlsruhe.de/ontology/ObjectType, Similarity: 0.7301638126373291
# 7. Entity: has format, URI: http://purls.helmholtz-metadaten.de/mwo/hasFormat, Similarity: 0.7290972471237183
# 8. Entity: has creator, URI: http://purls.helmholtz-metadaten.de/mwo/hasCreator, Similarity: 0.7288016676902771
#
#
# Text: What are the different data formats in the "BAM reference data"?
# 1. Entity: UDC, URI: http://purl.org/dc/elements/1.1/contributor, Similarity: 0.7897754311561584
# 2. Entity: File Format, URI: http://purl.org/dc/terms/FileFormat, Similarity: 0.7834638953208923
# 3. Entity: Computational Materials Repository (CMR), URI: http://demo.fiz-karlsruhe.de/matwerk/E1060241, Similarity: 0.7801300883293152
# 4. Entity: Electronic Structure Common Data Format (ESCDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1153922, Similarity: 0.7796722054481506
# 5. Entity: semantic expressivity, URI: http://nfdi.fiz-karlsruhe.de/ontology/SemanticExpressivity, Similarity: 0.7745339274406433
# 6. Entity: has format, URI: http://purls.helmholtz-metadaten.de/mwo/hasFormat, Similarity: 0.7711977958679199
# 7. Entity: NOMAD Metainfo, URI: http://demo.fiz-karlsruhe.de/matwerk/E1156961, Similarity: 0.7697939872741699
# 8. Entity: about material, URI: http://purls.helmholtz-metadaten.de/mwo/aboutMaterial, Similarity: 0.7670783996582031
#
#
# Text: What is the software version of "pacemaker"?
# 1. Entity: eLabFTW, URI: http://demo.fiz-karlsruhe.de/matwerk/E527852, Similarity: 0.7181330323219299
# 2. Entity: Qe-tools, URI: http://demo.fiz-karlsruhe.de/matwerk/E479732, Similarity: 0.7139264345169067
# 3. Entity: Phonon database at Kyoto university, URI: http://demo.fiz-karlsruhe.de/matwerk/E1074846, Similarity: 0.7111146450042725
# 4. Entity: Pyrho, URI: http://demo.fiz-karlsruhe.de/matwerk/E510546, Similarity: 0.7076436281204224
# 5. Entity: Graphical Expression of Materials Data (GEMD), URI: http://demo.fiz-karlsruhe.de/matwerk/E1155441, Similarity: 0.7032119631767273
# 6. Entity: software interface, URI: http://www.ebi.ac.uk/swo/SWO_9000050, Similarity: 0.7016438841819763
#
#
# Text: What is the field of research "BAM reference data"?
# 1. Entity: Phonon database at Kyoto university, URI: http://demo.fiz-karlsruhe.de/matwerk/E1074846, Similarity: 0.7492272257804871
# 2. Entity: has topic, URI: http://purls.helmholtz-metadaten.de/mwo/hasTopic, Similarity: 0.7417762279510498
# 3. Entity: Materials Platform for Data Science, URI: http://demo.fiz-karlsruhe.de/matwerk/E1035642, Similarity: 0.7333654761314392
# 4. Entity: Metadata schemes for materials science data, URI: http://demo.fiz-karlsruhe.de/matwerk/E1123752, Similarity: 0.7314412593841553
# 5. Entity: Diffusion Database (Kakusan), URI: http://demo.fiz-karlsruhe.de/matwerk/E1050077, Similarity: 0.729027271270752
# 6. Entity: resource, URI: http://nfdi.fiz-karlsruhe.de/ontology/Resource, Similarity: 0.7264857888221741
# 7. Entity: Workshop: Simulation workflows in materials modelling, URI: http://demo.fiz-karlsruhe.de/matwerk/E1245333, Similarity: 0.7250858545303345
# 8. Entity: has expertise in, URI: http://purls.helmholtz-metadaten.de/mwo/hasExpertiseIn, Similarity: 0.7222039103507996
#
#
# Text: What is the description of the "BAM reference data"?
# 1. Entity: instrument model, URI: http://purls.helmholtz-metadaten.de/mwo/instrumentModel, Similarity: 0.7631836533546448
# 2. Entity: about material, URI: http://purls.helmholtz-metadaten.de/mwo/aboutMaterial, Similarity: 0.7620682120323181
# 3. Entity: UDC, URI: http://purl.org/dc/elements/1.1/contributor, Similarity: 0.7579913139343262
# 4. Entity: has format, URI: http://purls.helmholtz-metadaten.de/mwo/hasFormat, Similarity: 0.7569304704666138
# 5. Entity: glossary, URI: http://nfdi.fiz-karlsruhe.de/ontology/Glossary, Similarity: 0.751581072807312
# 6. Entity: glossary, URI: https://nfdi.fiz-karlsruhe.de/ontology/Glossary, Similarity: 0.751581072807312
# 7. Entity: Electronic Structure Common Data Format (ESCDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1153922, Similarity: 0.7482319474220276
# 8. Entity: Computational Materials Repository (CMR), URI: http://demo.fiz-karlsruhe.de/matwerk/E1060241, Similarity: 0.7477960586547852
#
#
# Text: Who are the creators of the "BAM reference data"?
# 1. Entity: Electronic Structure Common Data Format (ESCDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1153922, Similarity: 0.7332724928855896
# 2. Entity: has creator, URI: http://purls.helmholtz-metadaten.de/mwo/hasCreator, Similarity: 0.7325448393821716
# 3. Entity: NOMAD Metainfo, URI: http://demo.fiz-karlsruhe.de/matwerk/E1156961, Similarity: 0.7286884188652039
# 4. Entity: Phonon database at Kyoto university, URI: http://demo.fiz-karlsruhe.de/matwerk/E1074846, Similarity: 0.7263903617858887
# 5. Entity: dateCreated, URI: https://schema.org/dateCreated, Similarity: 0.7200872898101807
# 6. Entity: The MatWerk ontology, URI: http://purls.helmholtz-metadaten.de/mwo/, Similarity: 0.7180271148681641
# 7. Entity: Carolina Materials Database, URI: http://demo.fiz-karlsruhe.de/matwerk/E1079247, Similarity: 0.7168002128601074
# 8. Entity: Atomistictools, URI: http://demo.fiz-karlsruhe.de/matwerk/E1031331, Similarity: 0.7137792706489563
#
#
# Text: What are the datasets published by "BAM"?
# 1. Entity: NOMAD Metainfo, URI: http://demo.fiz-karlsruhe.de/matwerk/E1156961, Similarity: 0.7672039270401001
# 2. Entity: about material, URI: http://purls.helmholtz-metadaten.de/mwo/aboutMaterial, Similarity: 0.7433327436447144
# 3. Entity: has creator, URI: http://purls.helmholtz-metadaten.de/mwo/hasCreator, Similarity: 0.7400168776512146
# 4. Entity: Electronic Structure Common Data Format (ESCDF), URI: http://demo.fiz-karlsruhe.de/matwerk/E1153922, Similarity: 0.7395100593566895
# 5. Entity: Phonon database at Kyoto university, URI: http://demo.fiz-karlsruhe.de/matwerk/E1074846, Similarity: 0.7333850860595703
# 6. Entity: Computational Materials Repository (CMR), URI: http://demo.fiz-karlsruhe.de/matwerk/E1060241, Similarity: 0.7311202883720398
# 7. Entity: Materials Data Repository, URI: http://demo.fiz-karlsruhe.de/matwerk/E1042847, Similarity: 0.7302395105361938
# 8. Entity: OpenBIS, URI: http://demo.fiz-karlsruhe.de/matwerk/E551726, Similarity: 0.7301573753356934

# %%
df_sentence = pd.read_excel('/content/SimilarEntities5+1.xlsx')#
df_sentence
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6             Molecular Dynamics" Software?
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   ['computational materials science', 'Computati...
# 1   ['Elemental Multiperspective Material Ontology...
# 2   ['datasets', 'dataset', 'Image data', 'data po...
# 3   ['Ebrahim Norouzi', 'Ahmad Zainul Ihsan', 'Mir...
# 4   ['paraview', 'ParaView', 'data portal', 'datas...
# 5   ['Dr.  Volker Hofmann', 'Niklas Siemer', 'Dr. ...
# 6   ['Atomic Simulation Recipes', 'Workshop: From ...
# 7   ['Molecular Dynamics (MD)', 'Crystallography O...
# 8   ['computational materials science', 'Computati...
# 9   ['Pyiron', 'Pyrho', 'pyDOE', 'cython', 'Pyreti...
# 10  ['Analytic bond-order potentials', 'Mechanical...
# 11  ['Python scripts', 'Java', 'python', 'Python',...
# 12  ['electronic lab notebook', 'Jupyter notebooks...
# 13  ['molecular dynamics', 'Visual Molecular Dynam...
# 14  ['computational materials science', 'Computati...
# 15  ['Elk', 'NOMAD', 'Novel Materials Discovery (N...
# 16  ['Ontologies for Materials Science', 'Computat...
# 17  ['acronym', 'Silicon', 'SIRIUS', 'Crystallogra...
# 18  ['acronym', 'project', 'project', 'Project', '...
# 19  ['ontology', 'ontology matching', 'The MatWerk...
# 20  ['Materials Project API', 'HybriD³ materials d...
# 21  ['specification', 'Silicon', 'acronym', 'softw...
# 22  ['MatDB Online', 'MatDB', 'Organic Materials D...
# 23  ['Proprietary license', 'Proprietary commercia...
# 24  ['Materials Cloud', 'Materials Commons', 'Mate...
# 25  ['Bundesanstalt für Materialforschung und -prü...
# 26  ['Mechanics of Materials', 'mechanics of mater...
# 27  ['Transmission electron microscopy', 'X-ray mi...
# 28  ['Elastic Constant Demo Data', 'Elastic Consta...
# 29  ['hardness data', 'educational resource', 'Car...
# 30  ['hardness data', 'educational resource', 'Car...
# 31  ['pacemaker', 'Atomman', 'matador', 'Plant mov...
# 32  ['hardness data', 'educational resource', 'Car...
# 33  ['hardness data', 'educational resource', 'Car...
# 34  ['Bochkarev, A., Lysogorskiy, Y., Menon, S., Q...
# 35  ['hardness data', 'educational resource', 'Car...
# 36  ['Bundesanstalt für Materialforschung und -prü...
#
#                                           Entity URIs
# 0   ['http://demo.fiz-karlsruhe.de/matwerk/E67431'...
# 1   ['http://demo.fiz-karlsruhe.de/matwerk/E112675...
# 2   ['http://demo.fiz-karlsruhe.de/matwerk/E117221...
# 3   ['http://demo.fiz-karlsruhe.de/matwerk/E15879'...
# 4   ['http://demo.fiz-karlsruhe.de/matwerk/E123109...
# 5   ['http://demo.fiz-karlsruhe.de/matwerk/E9912',...
# 6   ['http://demo.fiz-karlsruhe.de/matwerk/E552776...
# 7   ['http://demo.fiz-karlsruhe.de/matwerk/E61379'...
# 8   ['http://demo.fiz-karlsruhe.de/matwerk/E67431'...
# 9   ['http://demo.fiz-karlsruhe.de/matwerk/E457491...
# 10  ['http://demo.fiz-karlsruhe.de/matwerk/E40341'...
# 11  ['http://demo.fiz-karlsruhe.de/matwerk/E119837...
# 12  ['http://purls.helmholtz-metadaten.de/mwo/Elec...
# 13  ['http://demo.fiz-karlsruhe.de/matwerk/E616496...
# 14  ['http://demo.fiz-karlsruhe.de/matwerk/E67431'...
# 15  ['http://demo.fiz-karlsruhe.de/matwerk/E444212...
# 16  ['http://demo.fiz-karlsruhe.de/matwerk/E124788...
# 17  ['http://purl.obolibrary.org/obo/NCIT_C93495',...
# 18  ['http://purl.obolibrary.org/obo/NCIT_C93495',...
# 19  ['https://nfdi.fiz-karlsruhe.de/ontology/Ontol...
# 20  ['http://demo.fiz-karlsruhe.de/matwerk/E547536...
# 21  ['http://nfdi.fiz-karlsruhe.de/ontology/Specif...
# 22  ['http://demo.fiz-karlsruhe.de/matwerk/E114634...
# 23  ['http://demo.fiz-karlsruhe.de/matwerk/E748254...
# 24  ['http://demo.fiz-karlsruhe.de/matwerk/E102702...
# 25  ['http://demo.fiz-karlsruhe.de/matwerk/E124796...
# 26  ['http://demo.fiz-karlsruhe.de/matwerk/E52682'...
# 27  ['http://demo.fiz-karlsruhe.de/matwerk/E625404...
# 28  ['http://demo.fiz-karlsruhe.de/matwerk/E124741...
# 29  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 30  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 31  ['http://demo.fiz-karlsruhe.de/matwerk/E511556...
# 32  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 33  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 34  ['http://demo.fiz-karlsruhe.de/matwerk/E945626...
# 35  ['http://demo.fiz-karlsruhe.de/matwerk/E121390...
# 36  ['http://demo.fiz-karlsruhe.de/matwerk/E124796...

# %%
df_word = pd.read_excel('/content/phrase_similarity5+1X9.xlsx')
df_sentence = pd.read_excel('sentence_similarity.xlsx')
df_sentence.drop(columns=['Similarities'], inplace=True)

# and convert them if they are not
for col in ['Similar Entities', 'Entity URIs']:
    if not isinstance(df_word[col].iloc[0], list):
        df_word[col] = df_word[col].apply(eval)
    if not isinstance(df_sentence[col].iloc[0], list):
        df_sentence[col] = df_sentence[col].apply(eval)


# Perform the merge operation ensuring all entries from df_word are retained
df_merged = pd.merge(df_sentence, df_word, on='Text', how='right', suffixes=('_sentence', '_word'))

# Combine 'Similar Entities' and 'Entity URIs' columns while removing duplicates
df_merged['Similar Entities'] = df_merged.apply(
    lambda row: list(set((row['Similar Entities_sentence'] if isinstance(row['Similar Entities_sentence'], list) else []) +
                         (row['Similar Entities_word'] if isinstance(row['Similar Entities_word'], list) else []))),
    axis=1
)
df_merged['Entity URIs'] = df_merged.apply(
    lambda row: list(set((row['Entity URIs_sentence'] if isinstance(row['Entity URIs_sentence'], list) else []) +
                         (row['Entity URIs_word'] if isinstance(row['Entity URIs_word'], list) else []))),
    axis=1
)

# Drop the now redundant columns
df_merged.drop(columns=['Similar Entities_sentence', 'Similar Entities_word',
                        'Entity URIs_sentence', 'Entity URIs_word'], inplace=True)

# Let's check the merged dataframe
df_merged.to_excel('relevant_entities_relations.xlsx', index=False)

df_merged
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6             Molecular Dynamics" Software?
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                     Similar Relations  \
# 0   ['has work package', 'has expertise in', 'has ...
# 1   ['has related Project', 'related participant p...
# 2   ['has contributor', 'related participant proje...
# 3   ['has work package', 'has expertise in', 'has ...
# 4   ['has email address ', 'has postal address', '...
# 5   ['has affiliation', 'has curation status', 'ha...
# 6   ['has documentation', 'has bibliographic citat...
# 7   ['required tool', 'has related resource', 'rel...
# 8   ['has some values from', 'has work package', '...
# 9   ['has annotated source ', 'has bibliographic c...
# 10  ['has  description', 'has description', 'has b...
# 11  ['uses software', 'has example of usage', 'has...
# 12  ['has type', 'has object type', 'has media typ...
# 13  ['uses software', 'required tool', 'has operat...
# 14  ['has bibliographic citation', 'has  descripti...
# 15  ['has type', 'has object type', 'has media typ...
# 16  ['has repository', 'has website', 'has definit...
# 17  ['has instrument model', 'has first element', ...
# 18  ['has  description', 'has description', 'has b...
# 19  ['has related resource', 'related participant ...
# 20  ['has url', 'has file Extension', 'has reposit...
# 21  ['has  description', 'has description', 'has b...
# 22  ['has documentation', 'has bibliographic citat...
# 23  ['has type', 'has object type', 'has media typ...
# 24  ['has conforms to specification', 'belongs to'...
# 25  ['has definition source', 'has annotated sourc...
# 26  ['has some values from', 'has related resource...
# 27  ['has related resource', 'related participant ...
# 28  ['has license', 'has license', 'has affiliatio...
# 29  ['has repository', 'has annotated source ', 'h...
# 30  ['has format', 'has format', 'has documentatio...
# 31  ['has Version', 'uses software', 'has instrume...
# 32  ['has related task area', 'has discipline', 'h...
# 33  ['has  description', 'has description', 'has b...
# 34  ['has definition source', 'has annotated sourc...
# 35  ['has creator', 'has author', 'has contributor...
# 36  ['has repository', 'has bibliographic citation...
#
#                                         Relation URIs  \
# 0   ['https://nfdi.fiz-karlsruhe.de/ontology/examp...
# 1   ['https://schema.org/dateCreated', 'http://nfd...
# 2   ['http://www.geneontology.org/formats/oboInOwl...
# 3   ['https://nfdi.fiz-karlsruhe.de/ontology/examp...
# 4   ['http://purl.obolibrary.org/obo/IAO_0000119',...
# 5   ['http://purls.helmholtz-metadaten.de/mwo/isOn...
# 6   ['https://w3id.org/scholarlydata/ontology/conf...
# 7   ['http://purls.helmholtz-metadaten.de/mwo/hasW...
# 8   ['http://purls.helmholtz-metadaten.de/mwo/hasW...
# 9   ['http://emmo.info/emmo#EMMO_967080e5_2f42_4eb...
# 10  ['http://purl.obolibrary.org/obo/IAO_0000115',...
# 11  ['http://purls.helmholtz-metadaten.de/mwo/hasC...
# 12  ['http://purl.obolibrary.org/obo/IAO_0000111',...
# 13  ['http://purls.helmholtz-metadaten.de/mwo/hasC...
# 14  ['http://www.w3.org/2002/07/owl#sameAs', 'http...
# 15  ['http://purl.obolibrary.org/obo/IAO_0000111',...
# 16  ['http://purls.helmholtz-metadaten.de/mwo/uses...
# 17  ['http://www.w3.org/2004/02/skos/core#prefLabe...
# 18  ['http://purl.obolibrary.org/obo/IAO_0000115',...
# 19  ['http://purls.helmholtz-metadaten.de/mwo/hasL...
# 20  ['http://purls.helmholtz-metadaten.de/mwo/hasR...
# 21  ['http://purl.obolibrary.org/obo/IAO_0000115',...
# 22  ['https://w3id.org/scholarlydata/ontology/conf...
# 23  ['http://purl.obolibrary.org/obo/IAO_0000111',...
# 24  ['http://purls.helmholtz-metadaten.de/mwo/hasF...
# 25  ['http://purls.helmholtz-metadaten.de/mwo/hasC...
# 26  ['http://purls.helmholtz-metadaten.de/mwo/hasW...
# 27  ['http://purls.helmholtz-metadaten.de/mwo/hasL...
# 28  ['http://purl.org/dc/terms/format', 'http://ww...
# 29  ['http://purls.helmholtz-metadaten.de/mwo/uses...
# 30  ['http://www.ebi.ac.uk/swo/has_license', 'http...
# 31  ['http://purls.helmholtz-metadaten.de/mwo/keyw...
# 32  ['http://purls.helmholtz-metadaten.de/mwo/belo...
# 33  ['http://purl.obolibrary.org/obo/IAO_0000115',...
# 34  ['http://purls.helmholtz-metadaten.de/mwo/hasC...
# 35  ['http://purls.helmholtz-metadaten.de/mwo/hasA...
# 36  ['http://purls.helmholtz-metadaten.de/mwo/uses...
#
#                          Relation_uris_with_Namespace  \
# 0   ['mwo:hasWorkPackage', 'mwo:hasExpertiseIn', '...
# 1   ['nfdicore:relatedProject', 'mwo:relatedPartic...
# 2   ['mwo:hasContributor', 'mwo:relatedParticipant...
# 3   ['mwo:hasWorkPackage', 'mwo:hasExpertiseIn', '...
# 4   ['mwo:emailAddress', 'mwo:hasPostalAddress', '...
# 5   ['mwo:hasAffiliation', 'ns2:IAO_0000114', 'nfd...
# 6   ['mwo:hasDocumentation', 'dcterms:bibliographi...
# 7   ['mwo:requiredTool', 'mwo:hasRelatedResource',...
# 8   ['owl:someValuesFrom', 'mwo:hasWorkPackage', '...
# 9   ['owl:annotatedSource', 'dcterms:bibliographic...
# 10  ['dcterms:description', 'mwo:description', 'dc...
# 11  ['ns3:SWO_0000082', 'ns2:IAO_0000112', 'mwo:ha...
# 12  ['rdf:type', 'nfdicore:objectType', 'dc:contri...
# 13  ['ns3:SWO_0000082', 'mwo:requiredTool', 'schem...
# 14  ['dcterms:bibliographicCitation', 'dcterms:des...
# 15  ['rdf:type', 'nfdicore:objectType', 'dc:contri...
# 16  ['mwo:hasRepository', 'mwo:hasWebsite', 'ns2:I...
# 17  ['mwo:instrumentModel', 'rdf:first', 'mwo:hasD...
# 18  ['dcterms:description', 'mwo:description', 'dc...
# 19  ['mwo:hasRelatedResource', 'mwo:relatedPartici...
# 20  ['nfdicore:url', 'nfdicore:fileExtension', 'mw...
# 21  ['dcterms:description', 'mwo:description', 'dc...
# 22  ['mwo:hasDocumentation', 'dcterms:bibliographi...
# 23  ['rdf:type', 'nfdicore:objectType', 'dc:contri...
# 24  ['mwo:conformsToSpecification', 'mwo:belongsTo...
# 25  ['ns2:IAO_0000119', 'owl:annotatedSource', 'mw...
# 26  ['owl:someValuesFrom', 'mwo:hasRelatedResource...
# 27  ['mwo:hasRelatedResource', 'mwo:relatedPartici...
# 28  ['dcterms:license', 'ns3:has_license', 'mwo:ha...
# 29  ['mwo:hasRepository', 'owl:annotatedSource', '...
# 30  ['dcterms:format', 'mwo:hasFormat', 'mwo:hasDo...
# 31  ['mwo:hasVersion', 'ns3:SWO_0000082', 'mwo:ins...
# 32  ['mwo:relatedTaskArea', 'mwo:hasDiscipline', '...
# 33  ['dcterms:description', 'mwo:description', 'dc...
# 34  ['ns2:IAO_0000119', 'owl:annotatedSource', 'mw...
# 35  ['mwo:hasCreator', 'mwo:hasAuthor', 'mwo:hasCo...
# 36  ['mwo:hasRepository', 'dcterms:bibliographicCi...
#
#                                      Similar Entities  \
# 0   [Computational Material Science, computational...
# 1   [ruby, R. S. Elliott and E. B. Tadmor, "Knowle...
# 2   [Image data, Framework for curation and distri...
# 3   [Dr. Amir Laadhar, Mirza Mohtashim Alam, Ahmad...
# 4   [paraview, data portal, Standardised documenta...
# 5   [Prof. Dr.  Jörg Neugebauer, Markus Schilling,...
# 6   [controlled vocabulary, Atomic Simulation Reci...
# 7   [MDTraj, Pizza.py Toolkit, Silicon, Extensible...
# 8   [Computational Material Science, computational...
# 9   [pyDOE, cython, Pyretis, Pyrho, https://github...
# 10  [The ITAP Molecular Dynamics Program, NGLview,...
# 11  [measurement processing, Java, py4vasp, icet, ...
# 12  [Atomic Simulation Environment, Laboratory Ins...
# 13  [Silicon, Computational Chemistry, FitSNAP, fr...
# 14  [eNanoMapper ontology, computational materials...
# 15  [Silicon, Novel Materials Discovery (NOMAD), D...
# 16  [Computational Material Science, computational...
# 17  [Silicon, SIRIUS, acronym, Crystallography Ope...
# 18  [X-ray computed tomography, Tomography and Mic...
# 19  [The MatWerk ontology, MatPortal, ontology mat...
# 20  [Materials Platform for Data Science, Material...
# 21  [Silicon, programming language, py4vasp, R. S....
# 22  [Phonon database at Kyoto university, MatPorta...
# 23  [Proprietary license, documentation, software ...
# 24  [controlled vocabulary, The MatWerk ontology, ...
# 25  [BAM reference data: results of ASTM E139 -11 ...
# 26  [Polymer Database (PoLyInfo), Elastic Constant...
# 27  [Thermo-Calc, Computational Material Sample On...
# 28  [Fiji, Phonon database at Kyoto university, El...
# 29  [BAM reference data: results of ASTM E139 -11 ...
# 30  [BAM reference data: results of ASTM E139 -11 ...
# 31  [Phonon database at Kyoto university, pacemake...
# 32  [BAM reference data: results of ASTM E139 -11 ...
# 33  [BAM reference data: results of ASTM E139 -11 ...
# 34  [The Abinit project: Impact, environment and r...
# 35  [dateCreated, Phonon database at Kyoto univers...
# 36  [BAM reference data: results of ASTM E139 -11 ...
#
#                                           Entity URIs
# 0   [http://demo.fiz-karlsruhe.de/matwerk/E67431, ...
# 1   [http://demo.fiz-karlsruhe.de/matwerk/E837572,...
# 2   [http://demo.fiz-karlsruhe.de/matwerk/E1196832...
# 3   [http://demo.fiz-karlsruhe.de/matwerk/E10181, ...
# 4   [http://demo.fiz-karlsruhe.de/matwerk/E1231097...
# 5   [http://demo.fiz-karlsruhe.de/matwerk/E33641, ...
# 6   [http://demo.fiz-karlsruhe.de/matwerk/E63482, ...
# 7   [http://demo.fiz-karlsruhe.de/matwerk/E469997,...
# 8   [http://demo.fiz-karlsruhe.de/matwerk/E1066071...
# 9   [http://demo.fiz-karlsruhe.de/matwerk/E598872,...
# 10  [http://demo.fiz-karlsruhe.de/matwerk/E506516,...
# 11  [http://demo.fiz-karlsruhe.de/matwerk/E476801,...
# 12  [https://w3id.org/skgo/modsci#LaboratoryInstru...
# 13  [http://purl.obolibrary.org/obo/NCIT_C42610, h...
# 14  [http://demo.fiz-karlsruhe.de/matwerk/E1245261...
# 15  [http://demo.fiz-karlsruhe.de/matwerk/E1247879...
# 16  [http://purls.helmholtz-metadaten.de/mwo/Mater...
# 17  [http://demo.fiz-karlsruhe.de/matwerk/E542321,...
# 18  [http://demo.fiz-karlsruhe.de/matwerk/E1248178...
# 19  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 20  [http://demo.fiz-karlsruhe.de/matwerk/E478754,...
# 21  [http://demo.fiz-karlsruhe.de/matwerk/E476801,...
# 22  [http://demo.fiz-karlsruhe.de/matwerk/E1074846...
# 23  [http://www.ebi.ac.uk/swo/license/SWO_1000002,...
# 24  [http://nfdi.fiz-karlsruhe.de/ontology/Control...
# 25  [http://demo.fiz-karlsruhe.de/matwerk/E4571, h...
# 26  [http://purls.helmholtz-metadaten.de/mwo/Mater...
# 27  [http://purls.helmholtz-metadaten.de/mwo/Mater...
# 28  [http://demo.fiz-karlsruhe.de/matwerk/E1074846...
# 29  [http://purl.org/dc/elements/1.1/contributor, ...
# 30  [http://purl.org/dc/elements/1.1/contributor, ...
# 31  [http://demo.fiz-karlsruhe.de/matwerk/E527852,...
# 32  [http://demo.fiz-karlsruhe.de/matwerk/E1074846...
# 33  [http://purl.org/dc/elements/1.1/contributor, ...
# 34  [http://demo.fiz-karlsruhe.de/matwerk/E941507,...
# 35  [http://demo.fiz-karlsruhe.de/matwerk/E1074846...
# 36  [http://demo.fiz-karlsruhe.de/matwerk/E4571, h...
